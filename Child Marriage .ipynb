# %%
# Importing the required package
import pandas as pd

# %%
# Importing the dataset
child_marriage = pd.read_excel('/content/safeher.xlsx', sheet_name = 'Sheet1')
child_marriage
# Out:
#     countries and area  Married by 15 Female  Married by 18 Female  \
# 0          Afghanistan                     4                    28
# 1              Albania                     1                    12
# 2              Algeria                     0                     4
# 3               Angola                     8                    30
# 4              Armenia                     0                     5
# ..                 ...                   ...                   ...
# 125            Vanuatu                     3                    21
# 126            Vietnam                     1                    11
# 127              Yemen                     9                    32
# 128             Zambia                     5                    29
# 129           Zimbabwe                     5                    34
#
#      Reference Year Female Data0Source0Female  Married by 18 Male  \
# 0                     2017       ALCS02016017                   7
# ...

# %%
# To select the Required columns for Analysis
Omo= child_marriage[['countries and area', 'Married by 15 Female', 'Married by 18 Female', 'Reference Year Female','Continent/region']]
Omo
# Out:
#     countries and area  Married by 15 Female  Married by 18 Female  \
# 0          Afghanistan                     4                    28
# 1              Albania                     1                    12
# 2              Algeria                     0                     4
# 3               Angola                     8                    30
# 4              Armenia                     0                     5
# ..                 ...                   ...                   ...
# 125            Vanuatu                     3                    21
# 126            Vietnam                     1                    11
# 127              Yemen                     9                    32
# 128             Zambia                     5                    29
# 129           Zimbabwe                     5                    34
#
#      Reference Year Female Continent/region
# 0                     2017             Asia
# 1                     2018           Europe
# ...

# %% [markdown]
# # **TOP 10 COUNTRIES WITH THE HIGHEST PREVALENCE OF CHILD MARRIAGE**

# %%
# To set 'countries and area' column as index
Omo_indexed = Omo.set_index('countries and area')
Omo_indexed
# Out:
#                     Married by 15 Female  Married by 18 Female  \
# countries and area
# Afghanistan                            4                    28
# Albania                                1                    12
# Algeria                                0                     4
# Angola                                 8                    30
# Armenia                                0                     5
# ...                                  ...                   ...
# Vanuatu                                3                    21
# Vietnam                                1                    11
# Yemen                                  9                    32
# Zambia                                 5                    29
# Zimbabwe                               5                    34
#
#                     Reference Year Female Continent/region
# countries and area
# Afghanistan                          2017             Asia
# ...

# %%
# To select the columns for top 10 and bottom 10
Top_10 =Omo_indexed[['Married by 15 Female', 'Married by 18 Female']]
Top_10
# Out:
#                     Married by 15 Female  Married by 18 Female
# countries and area
# Afghanistan                            4                    28
# Albania                                1                    12
# Algeria                                0                     4
# Angola                                 8                    30
# Armenia                                0                     5
# ...                                  ...                   ...
# Vanuatu                                3                    21
# Vietnam                                1                    11
# Yemen                                  9                    32
# Zambia                                 5                    29
# Zimbabwe                               5                    34
#
# [130 rows x 2 columns]

# %%
# To sort columns in descending order
Top_10_sorted = Top_10.sort_values(by=['Married by 15 Female', 'Married by 18 Female',], ascending=[False, False])
Top_10_sorted
# Out:
#                           Married by 15 Female  Married by 18 Female
# countries and area
# Niger                                       28                    76
# Central African Republic                    26                    61
# Chad                                        24                    61
# Mauritania                                  18                    37
# Mozambique                                  17                    53
# ...                                        ...                   ...
# Tunisia                                      0                     2
# North Korea                                  0                     0
# Lithuania                                    0                     0
# Singapore                                    0                     0
# United Kingdom                               0                     0
#
# [130 rows x 2 columns]

# %%
# To select the top 10 countries in child marriage prevalence
Top_countries =Top_10_sorted.head(10)
Top_countries
# Out:
#                           Married by 15 Female  Married by 18 Female
# countries and area
# Niger                                       28                    76
# Central African Republic                    26                    61
# Chad                                        24                    61
# Mauritania                                  18                    37
# Mozambique                                  17                    53
# Guinea                                      17                    47
# Somalia                                     17                    36
# Mali                                        16                    54
# Bangladesh                                  16                    51
# Nigeria                                     16                    43

# %%
# Import the required packages
import pandas as pd
import plotly.graph_objects as go

# %%
fig = go.Figure(go.Bar(
    y=Top_countries.index,
    x=Top_countries['Married by 15 Female'],
    name='Married by 15 Female',
    orientation='h',
    marker=dict(color='darkblue')
))

# %%
fig.add_trace(go.Bar(
    y=Top_countries.index,
    x=Top_countries['Married by 18 Female'],
    name='Married by 18 Female',
    orientation='h',
    marker=dict(color='lightblue')
))

# %%
fig.update_layout(
    title='Top 10 countries with child marriage prevalence at Age 15 and 18',
    xaxis_title='Percentage',
    yaxis_title='Countries'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **BOTTOM 10 COUNTRIES WITH THE LOWEST PREVALENCE OF CHILD MARRIAGE**

# %%
Omo_indexed
# Out:
#                     Married by 15 Female  Married by 18 Female  \
# countries and area
# Afghanistan                            4                    28
# Albania                                1                    12
# Algeria                                0                     4
# Angola                                 8                    30
# Armenia                                0                     5
# ...                                  ...                   ...
# Vanuatu                                3                    21
# Vietnam                                1                    11
# Yemen                                  9                    32
# Zambia                                 5                    29
# Zimbabwe                               5                    34
#
#                     Reference Year Female Continent/region
# countries and area
# Afghanistan                          2017             Asia
# ...

# %%
# To select the columns for bottom 10
Bottom_10 =Omo_indexed[['Married by 15 Female', 'Married by 18 Female']]
Bottom_10
# Out:
#                     Married by 15 Female  Married by 18 Female
# countries and area
# Afghanistan                            4                    28
# Albania                                1                    12
# Algeria                                0                     4
# Angola                                 8                    30
# Armenia                                0                     5
# ...                                  ...                   ...
# Vanuatu                                3                    21
# Vietnam                                1                    11
# Yemen                                  9                    32
# Zambia                                 5                    29
# Zimbabwe                               5                    34
#
# [130 rows x 2 columns]

# %%
# to sort in ascending order
Bottom_10_sorted = Bottom_10.sort_values(by=['Married by 15 Female', 'Married by 18 Female'], ascending=[True, True])
Bottom_10_sorted
# Out:
#                           Married by 15 Female  Married by 18 Female
# countries and area
# North Korea                                  0                     0
# Lithuania                                    0                     0
# Singapore                                    0                     0
# United Kingdom                               0                     0
# Maldives                                     0                     2
# ...                                        ...                   ...
# Mozambique                                  17                    53
# Mauritania                                  18                    37
# Chad                                        24                    61
# Central African Republic                    26                    61
# Niger                                       28                    76
#
# [130 rows x 2 columns]

# %%
# Select rows with specific index values
selected_rows_loc = Bottom_10_sorted.loc[['Maldives', 'Tunisia', 'Algeria', 'Bosnia and Herzegovina', 'Qatar', 'Armenia','Belarus', 'Turkmenistan', 'Kazakhstan', 'Rwanda']]  # Select rows with specific index values
selected_rows_loc
# Out:
#                         Married by 15 Female  Married by 18 Female
# countries and area
# Maldives                                   0                     2
# Tunisia                                    0                     2
# Algeria                                    0                     4
# Bosnia and Herzegovina                     0                     4
# Qatar                                      0                     4
# Armenia                                    0                     5
# Belarus                                    0                     5
# Turkmenistan                               0                     6
# Kazakhstan                                 0                     7
# Rwanda                                     0                     7

# %%
# To import the required packages
import pandas as pd
import plotly.graph_objects as go

# %%
fig = go.Figure(go.Bar(
    y=selected_rows_loc.index,
    x=selected_rows_loc['Married by 15 Female'],
    name='Married by 15 Female',
    orientation='h',
    marker=dict(color='lightblue')
))

# %%
fig.add_trace(go.Bar(
    y=selected_rows_loc.index,
    x=selected_rows_loc['Married by 18 Female'],
    name='Married by 18 Female',
    orientation='h',
    marker=dict(color='darkblue'),
))

# %%
fig.update_layout(
    title='Bottom 10 countries with child marriage prevalence at Age 15 and 18',
    xaxis_title='Percentage',
    yaxis_title='Countries'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
#  **No bar was displayed for Category 15 due to the zero values.**

# %% [markdown]
# # **PERCENTAGE OF MARRIAGE CATEGORIES BY CONTINENT**

# %%
Omo
# Out:
#     countries and area  Married by 15 Female  Married by 18 Female  \
# 0          Afghanistan                     4                    28
# 1              Albania                     1                    12
# 2              Algeria                     0                     4
# 3               Angola                     8                    30
# 4              Armenia                     0                     5
# ..                 ...                   ...                   ...
# 125            Vanuatu                     3                    21
# 126            Vietnam                     1                    11
# 127              Yemen                     9                    32
# 128             Zambia                     5                    29
# 129           Zimbabwe                     5                    34
#
#      Reference Year Female Continent/region
# 0                     2017             Asia
# 1                     2018           Europe
# ...

# %% [markdown]
# # **GLOBAL PERCENTAGE FOR CATEGORY 15**

# %%
# to select columns for category 15
Global_15_Percentage = Omo [["Continent/region", "Married by 15 Female"]]
Global_15_Percentage
# Out:
#     Continent/region  Married by 15 Female
# 0               Asia                     4
# 1             Europe                     1
# 2             Africa                     0
# 3             Africa                     8
# 4               Asia                     0
# ..               ...                   ...
# 125        Australia                     3
# 126             Asia                     1
# 127             Asia                     9
# 128           Africa                     5
# 129           Africa                     5
#
# [130 rows x 2 columns]

# %%
continent_totals = Global_15_Percentage.groupby('Continent/region')['Married by 15 Female'].sum()
continent_totals
# Out:
# Continent/region
# Africa           439
# Asia             100
# Australia         28
# Europe             4
# North America     84
# South America     34
# Name: Married by 15 Female, dtype: int64

# %%
# To calculate the percentage of each continent under the Married by 15 Category
continent_percentage = (continent_totals / continent_totals.sum() * 100).round().astype(int)
continent_percentage
# Out:
# Continent/region
# Africa           64
# Asia             15
# Australia         4
# Europe            1
# North America    12
# South America     5
# Name: Married by 15 Female, dtype: int64

# %%
# To convert the output into a DataFrame
continent_percentage_Global_15_Percentage = pd.DataFrame({'Percentage of Category 15': continent_percentage})
continent_percentage_Global_15_Percentage
# Out:
#                   Percentage of Category 15
# Continent/region
# Africa                                   64
# Asia                                     15
# Australia                                 4
# Europe                                    1
# North America                            12
# South America                             5

# %%
# To import the required packages for charts, color intensity.
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px

# %%
values =continent_percentage_Global_15_Percentage['Percentage of Category 15'].round().astype(int)

# %%
fig = go.Figure(go.Pie(
    labels=continent_percentage_Global_15_Percentage.index,
    values=values, marker=dict(colors= px.colors.sequential.Blues_r),
))

# %%
fig.update_layout(
    title='Percentage of Category 15 by continent', width=800,
    height=600
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **GLOBAL PERCENTAGE FOR CATEGORY 18**

# %%
# to select columns for category 18
Global_18_Percentage = Omo [["Continent/region", "Married by 18 Female"]]
Global_18_Percentage
# Out:
#     Continent/region  Married by 18 Female
# 0               Asia                    28
# 1             Europe                    12
# 2             Africa                     4
# 3             Africa                    30
# 4               Asia                     5
# ..               ...                   ...
# 125        Australia                    21
# 126             Asia                    11
# 127             Asia                    32
# 128           Africa                    29
# 129           Africa                    34
#
# [130 rows x 2 columns]

# %%
continent_totals = Global_18_Percentage.groupby('Continent/region')['Married by 18 Female'].sum()
continent_totals
# Out:
# Continent/region
# Africa           1540
# Asia              568
# Australia         167
# Europe             62
# North America     379
# South America     198
# Name: Married by 18 Female, dtype: int64

# %%
# To calculate the percentage of each continent under the Married by 15 Category
continent_percentage = (continent_totals / continent_totals.sum() * 100).round().astype(int)
continent_percentage
# Out:
# Continent/region
# Africa           53
# Asia             19
# Australia         6
# Europe            2
# North America    13
# South America     7
# Name: Married by 18 Female, dtype: int64

# %%
# To convert the output into a DataFrame
continent_percentage_Global_18_Percentage = pd.DataFrame({'Percentage of Category 18': continent_percentage})
continent_percentage_Global_18_Percentage
# Out:
#                   Percentage of Category 18
# Continent/region
# Africa                                   53
# Asia                                     19
# Australia                                 6
# Europe                                    2
# North America                            13
# South America                             7

# %%
# To import the required packages for charts, color intensity.
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px

# %%
values =continent_percentage_Global_18_Percentage['Percentage of Category 18'].round().astype(int)

# %%
fig = go.Figure(go.Pie(
    labels=continent_percentage_Global_18_Percentage.index,
    values=values, marker=dict(colors= px.colors.sequential.Blues_r),
))

# %%
fig.update_layout(
    title='Percentage of Category 18 by continent', width=800,
    height=600
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **WORLD MAP**

# %%
# Import the required pacakges
import pandas as pd
import folium
import geopandas as gpd

# %%
Omo
# Out:
#     countries and area  Married by 15 Female  Married by 18 Female  \
# 0          Afghanistan                     4                    28
# 1              Albania                     1                    12
# 2              Algeria                     0                     4
# 3               Angola                     8                    30
# 4              Armenia                     0                     5
# ..                 ...                   ...                   ...
# 125            Vanuatu                     3                    21
# 126            Vietnam                     1                    11
# 127              Yemen                     9                    32
# 128             Zambia                     5                    29
# 129           Zimbabwe                     5                    34
#
#      Reference Year Female Continent/region
# 0                     2017             Asia
# 1                     2018           Europe
# ...

# %%
# To select columns for the world map
Map_columns = Omo[['countries and area', 'Married by 15 Female', 'Married by 18 Female']]
Map_columns
# Out:
#     countries and area  Married by 15 Female  Married by 18 Female
# 0          Afghanistan                     4                    28
# 1              Albania                     1                    12
# 2              Algeria                     0                     4
# 3               Angola                     8                    30
# 4              Armenia                     0                     5
# ..                 ...                   ...                   ...
# 125            Vanuatu                     3                    21
# 126            Vietnam                     1                    11
# 127              Yemen                     9                    32
# 128             Zambia                     5                    29
# 129           Zimbabwe                     5                    34
#
# [130 rows x 3 columns]

# %%
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import plot

# %%
# To Melt the DataFrame to reshape it for Plotly Express
melted_Map_columns = Map_columns.melt(id_vars='countries and area', var_name='Category', value_name='Percentage')

# %%
fig = px.choropleth(melted_Map_columns,
                    locations='countries and area',
                    locationmode='country names',
                    color='Percentage',
                    hover_name='countries and area',
                    projection='natural earth',
                    animation_frame='Category',  # Separate frames for each category
                    title='Marriages at 15 vs Marriages at 18 (%)', color_continuous_scale='Blues')

# %%
fig.update_layout(width=1100, height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Percentage Distribution of African Countries contributing to Child Marriage**

# %%
# To select the Required columns for Analysis
Omo= child_marriage[['countries and area', 'Married by 15 Female', 'Married by 18 Female','Continent/region']]
Omo
# Out:
#     countries and area  Married by 15 Female  Married by 18 Female  \
# 0          Afghanistan                     4                    28
# 1              Albania                     1                    12
# 2              Algeria                     0                     4
# 3               Angola                     8                    30
# 4              Armenia                     0                     5
# ..                 ...                   ...                   ...
# 125            Vanuatu                     3                    21
# 126            Vietnam                     1                    11
# 127              Yemen                     9                    32
# 128             Zambia                     5                    29
# 129           Zimbabwe                     5                    34
#
#     Continent/region
# 0               Asia
# 1             Europe
# 2             Africa
# 3             Africa
# 4               Asia
# ..               ...
# ...

# %%
Africa_Omo = Omo[Omo['Continent/region'] == 'Africa']
Africa_Omo
# Out:
#                    countries and area  Married by 15 Female  \
# 2                             Algeria                     0
# 3                              Angola                     8
# 10                              Benin                     9
# 15                       Burkina Faso                    10
# 16                            Burundi                     3
# 17                         Cape Verde                     3
# 19                           Cameroon                    11
# 20           Central African Republic                    26
# 21                               Chad                    24
# 22                           Colombia                     5
# 23                            Comoros                    10
# 24              Republic of the Congo                     7
# 26                        Ivory Coast                     7
# 29   Democratic Republic of the Congo                     8
# 30                           Djibouti                     1
# ...

# %%
Africa_15 = Africa_Omo[['countries and area', 'Married by 15 Female', 'Married by 18 Female']]
Africa_15
# Out:
#                    countries and area  Married by 15 Female  \
# 2                             Algeria                     0
# 3                              Angola                     8
# 10                              Benin                     9
# 15                       Burkina Faso                    10
# 16                            Burundi                     3
# 17                         Cape Verde                     3
# 19                           Cameroon                    11
# 20           Central African Republic                    26
# 21                               Chad                    24
# 22                           Colombia                     5
# 23                            Comoros                    10
# 24              Republic of the Congo                     7
# 26                        Ivory Coast                     7
# 29   Democratic Republic of the Congo                     8
# 30                           Djibouti                     1
# ...

# %%
Africa_15 = Africa_Omo[['countries and area', 'Married by 15 Female']]
Africa_15
# Out:
#                    countries and area  Married by 15 Female
# 2                             Algeria                     0
# 3                              Angola                     8
# 10                              Benin                     9
# 15                       Burkina Faso                    10
# 16                            Burundi                     3
# 17                         Cape Verde                     3
# 19                           Cameroon                    11
# 20           Central African Republic                    26
# 21                               Chad                    24
# 22                           Colombia                     5
# 23                            Comoros                    10
# 24              Republic of the Congo                     7
# 26                        Ivory Coast                     7
# 29   Democratic Republic of the Congo                     8
# 30                           Djibouti                     1
# ...

# %%
Africa_15_indexed = Africa_15.set_index('countries and area', inplace=True)

# %%
fifteen = 'Married by 15 Female'

# %%
Sum_15 = Africa_15[fifteen].sum()
Sum_15
# Out:
# 439

# %%
Africa_15['percentage'] = round((Africa_15[fifteen] / Sum_15) * 100).astype(int)
Africa_15['percentage']
# Out:
# <ipython-input-88-8ae635b49943>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# countries and area
# Algeria                             0
# Angola                              2
# Benin                               2
# Burkina Faso                        2
# Burundi                             1
# Cape Verde                          1
# Cameroon                            3
# Central African Republic            6
# Chad                                5
# Colombia                            1
# Comoros                             2
# Republic of the Congo               2
# Ivory Coast                         2
# Democratic Republic of the Congo    2
# Djibouti                            0
# Egypt                               0
# ...

# %%
Africa_15_indexed.reset_index(inplace=True)
Africa_15_indexed
# Out:
#     index                countries and area  Married by 15 Female  percentage
# 0       0                           Algeria                     0           0
# 1       1                            Angola                     8           2
# 2       2                             Benin                     9           2
# 3       3                      Burkina Faso                    10           2
# 4       4                           Burundi                     3           1
# 5       5                        Cape Verde                     3           1
# 6       6                          Cameroon                    11           3
# 7       7          Central African Republic                    26           6
# 8       8                              Chad                    24           5
# 9       9                          Colombia                     5           1
# 10     10                           Comoros                    10           2
# ...

# %%
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import plot

# %%
blue_colorscale = [(0, '#F0F8FF'), (1, '#00008B')]  # Light to dark blue

# %%
# Create a choropleth trace
fig = go.Figure(data=go.Choropleth(
    locations=Africa_15_indexed['countries and area'],
    z=Africa_15_indexed['percentage'],
    locationmode='country names',
    colorscale=blue_colorscale,
    colorbar_title='Percentage'
))

# %%
fig.update_layout(
    title_text='Percentage distribution of countries for Category 15 in Africa',
    geo=dict(
        showcoastlines=True,
        projection_type='equirectangular'
    )
)

# %%
fig.update_layout(width=1100, height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Africa_18 = Africa_Omo[['countries and area', 'Married by 18 Female']]
Africa_18
# Out:
#                    countries and area  Married by 18 Female
# 2                             Algeria                     4
# 3                              Angola                    30
# 10                              Benin                    31
# 15                       Burkina Faso                    52
# 16                            Burundi                    19
# 17                         Cape Verde                    18
# 19                           Cameroon                    30
# 20           Central African Republic                    61
# 21                               Chad                    61
# 22                           Colombia                    23
# 23                            Comoros                    32
# 24              Republic of the Congo                    27
# 26                        Ivory Coast                    27
# 29   Democratic Republic of the Congo                    29
# 30                           Djibouti                     5
# ...

# %%
Africa_18.set_index('countries and area', inplace=True)

# %%
eighteen = 'Married by 18 Female'

# %%
total = Africa_18[eighteen].sum()
total
# Out:
# 1540

# %%
Africa_18 ['percentage'] = round((Africa_18[eighteen] / total) * 100).astype(int)
Africa_18 ['percentage']

# %%
Africa_18.reset_index(inplace=True)
Africa_18
# Out:
#                   countries and area  Married by 18 Female  percentage
# 0                            Algeria                     4           0
# 1                             Angola                    30           2
# 2                              Benin                    31           2
# 3                       Burkina Faso                    52           3
# 4                            Burundi                    19           1
# 5                         Cape Verde                    18           1
# 6                           Cameroon                    30           2
# 7           Central African Republic                    61           4
# 8                               Chad                    61           4
# 9                           Colombia                    23           1
# 10                           Comoros                    32           2
# 11             Republic of the Congo                    27           2
# ...

# %%
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import plot

# %%
blue_colorscale = [(0, '#F0F8FF'), (1, '#00008B')]  # Light to dark blue

# %%
# Create a choropleth trace
fig = go.Figure(data=go.Choropleth(
    locations=Africa_18 ['countries and area'],
    z=Africa_18 ['percentage'],
    locationmode='country names',  # To Set location mode to country names
    colorscale=blue_colorscale,  # To Choose a colorscale
    colorbar_title='Percentage',  # Title for the color bar
))

# %%
fig.update_layout(
    title_text='Percentage distribution of countries for Category 18 in Africa',
    geo=dict(
        showcoastlines=True,  # Show coastlines
        projection_type='equirectangular'
    )
)

# %%
fig.update_layout(width=1100, height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
